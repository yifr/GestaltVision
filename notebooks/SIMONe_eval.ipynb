# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os
import sys
sys.path.append("../")
from data import gestalt
from models import SIMONe, bvae
# %load_ext autoreload
# %autoreload 2
import torch.nn.functional as F
from tqdm import tqdm_notebook

# %%
model_checkpoint_dir = "/om2/user/yyf/GestaltVision/saved_models/SAVI/tex=all_shapes=2,3_slots=4"
models = os.listdir(model_checkpoint_dir)
models.sort()

latest = models[-1]
model_chkpt = os.path.join(model_checkpoint_dir, latest)
chkpt = torch.load(model_chkpt, map_location="cpu")

# %%
data = gestalt.Gestalt(top_level=["voronoi"], sub_level=["superquadric_3", "superquadric_4"], 
                       frames_per_scene=10,
                        passes=["depths"])
data.training = True
# Out:
# 12638 # training scenes, 1402 # test scenes

# %%
batch = torch.stack([data.__getitem__(i)["depths"] for i in [1]], 0)
images = batch

# %%
images.shape
# Out:
# torch.Size([1, 10, 3, 128, 128])

# %%
simone = SIMONe.SIMONE(images.shape, 128, K_slots=16).to("cuda")

# %%
track_losses = []
optim = torch.optim.Adam(simone.parameters(), lr=2e-3)
for i in tqdm_notebook(range(300)):
    optim.zero_grad()
    images = images.to("cuda")
    out = simone(images)
    losses = simone.compute_loss(images, out)
    losses["total_loss"].backward()
    optim.step()
    track_losses.append(losses["total_loss"].item())
    print(losses["total_loss"].item())
# Out:
# /tmp/ipykernel_11884/1445976237.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(300)):
#   0%|          | 0/300 [00:00<?, ?it/s]
# torch.Size([1, 10, 128, 8, 8])
# 3.1216158866882324
# torch.Size([1, 10, 128, 8, 8])
# 2.9622700214385986
# torch.Size([1, 10, 128, 8, 8])
# 2.9736039638519287
# torch.Size([1, 10, 128, 8, 8])
# 2.9522571563720703
# torch.Size([1, 10, 128, 8, 8])
# 2.941179037094116
# torch.Size([1, 10, 128, 8, 8])
# 2.940478801727295
# torch.Size([1, 10, 128, 8, 8])
# 2.9397056102752686
# torch.Size([1, 10, 128, 8, 8])
# 2.939922332763672
# torch.Size([1, 10, 128, 8, 8])
# 2.937129497528076
# torch.Size([1, 10, 128, 8, 8])
# 2.9324162006378174
# torch.Size([1, 10, 128, 8, 8])
# 2.932297468185425
# torch.Size([1, 10, 128, 8, 8])
# 2.931688070297241
# torch.Size([1, 10, 128, 8, 8])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11884/1445976237.py in <module>
#       4     optim.zero_grad()
#       5     images = images.to("cuda")
# ----> 6     out = simone(images)
#       7     losses = simone.compute_loss(images, out)
#       8     losses["total_loss"].backward()
#
# /om2/user/yyf/miniconda/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/GestaltVision/notebooks/../models/SIMONe.py in forward(self, x, decode_idxs)
#     285         B, T, C, H, W = x.shape
#     286         object_dists, frame_dists = self.encode(x)
# --> 287         pixel_means, mixture_logits = self.decode(
#     288             object_dists, frame_dists, (B, T, C, H, W))
#     289
#
# ~/GestaltVision/notebooks/../models/SIMONe.py in decode(self, object_dists, frame_dists, batch_size)
#     272             inputs = inputs.reshape(B * T, channels,  -1)
#     273
# --> 274             out = self.decoder(inputs)
#     275             out = out.reshape(B, T, H, W, -1)
#     276
#
# /om2/user/yyf/miniconda/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /om2/user/yyf/miniconda/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /om2/user/yyf/miniconda/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /om2/user/yyf/miniconda/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299
#     300     def forward(self, input: Tensor) -> Tensor:
# --> 301         return self._conv_forward(input, self.weight, self.bias)
#     302
#     303
#
# /om2/user/yyf/miniconda/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     295                             weight, bias, self.stride,
#     296                             _single(0), self.dilation, self.groups)
# --> 297         return F.conv1d(input, weight, bias, self.stride,
#     298                         self.padding, self.dilation, self.groups)
#     299
#
# KeyboardInterrupt:

# %%
plt.plot(range(len(track_losses)), track_losses)

# %%
recons = out["recons"].detach().cpu().numpy()

# %%
for i in range(6):
    fig, axs = plt.subplots(1, 2, figsize=(16, 8))
    axs[0].imshow(images[0,i].detach().cpu().numpy().transpose(1, 2, 0))
    axs[1].imshow(recons[0,i])
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for i in range(T):
    print(time_frames[0, i].min(), time_frames[0, i].max())
# Out:
# tensor(0., device='cuda:0') tensor(0., device='cuda:0')
# tensor(0.1111, device='cuda:0') tensor(0.1111, device='cuda:0')
# tensor(0.2222, device='cuda:0') tensor(0.2222, device='cuda:0')
# tensor(0.3333, device='cuda:0') tensor(0.3333, device='cuda:0')
# tensor(0.4444, device='cuda:0') tensor(0.4444, device='cuda:0')
# tensor(0.5556, device='cuda:0') tensor(0.5556, device='cuda:0')
# tensor(0.6667, device='cuda:0') tensor(0.6667, device='cuda:0')
# tensor(0.7778, device='cuda:0') tensor(0.7778, device='cuda:0')
# tensor(0.8889, device='cuda:0') tensor(0.8889, device='cuda:0')
# tensor(1., device='cuda:0') tensor(1., device='cuda:0')

# %%
recons = out["recons"].squeeze(0).detach().cpu().numpy()
masks = out["masks"].squeeze(0).detach().cpu().numpy()
slots = out["slots"].squeeze(0).detach().cpu().numpy()
recon_all = out["recon_combined"].squeeze(0).detach().cpu().numpy()

# %%
spatial_coords = torch.linspace(-1, 1, H)
xv, yv = torch.meshgrid([spatial_coords, spatial_coords], indexing="xy")
ll = torch.stack([xv, yv], -1)
decode_idxs = einops.repeat(ll, "H W X -> B T H W X", B=B, T=T)

# %%
masks.shape
# Out:
# (6, 4, 128, 128, 1)

# %%
decode_idxs[0, 0, :, 0]
# Out:
# tensor([[-1.0000, -1.0000],
#         [-1.0000, -0.9843],
#         [-1.0000, -0.9685],
#         [-1.0000, -0.9528],
#         [-1.0000, -0.9370],
#         [-1.0000, -0.9213],
#         [-1.0000, -0.9055],
#         [-1.0000, -0.8898],
#         [-1.0000, -0.8740],
#         [-1.0000, -0.8583],
#         [-1.0000, -0.8425],
#         [-1.0000, -0.8268],
#         [-1.0000, -0.8110],
#         [-1.0000, -0.7953],
#         [-1.0000, -0.7795],
#         [-1.0000, -0.7638],
#         [-1.0000, -0.7480],
#         [-1.0000, -0.7323],
#         [-1.0000, -0.7165],
#         [-1.0000, -0.7008],
#         [-1.0000, -0.6850],
#         [-1.0000, -0.6693],
#         [-1.0000, -0.6535],
#         [-1.0000, -0.6378],
#         [-1.0000, -0.6220],
#         [-1.0000, -0.6063],
#         [-1.0000, -0.5906],
#         [-1.0000, -0.5748],
#         [-1.0000, -0.5591],
#         [-1.0000, -0.5433],
#         [-1.0000, -0.5276],
#         [-1.0000, -0.5118],
#         [-1.0000, -0.4961],
#         [-1.0000, -0.4803],
#         [-1.0000, -0.4646],
#         [-1.0000, -0.4488],
#         [-1.0000, -0.4331],
#         [-1.0000, -0.4173],
#         [-1.0000, -0.4016],
#         [-1.0000, -0.3858],
#         [-1.0000, -0.3701],
#         [-1.0000, -0.3543],
#         [-1.0000, -0.3386],
#         [-1.0000, -0.3228],
#         [-1.0000, -0.3071],
#         [-1.0000, -0.2913],
#         [-1.0000, -0.2756],
#         [-1.0000, -0.2598],
#         [-1.0000, -0.2441],
#         [-1.0000, -0.2283],
#         [-1.0000, -0.2126],
#         [-1.0000, -0.1969],
#         [-1.0000, -0.1811],
#         [-1.0000, -0.1654],
#         [-1.0000, -0.1496],
#         [-1.0000, -0.1339],
#         [-1.0000, -0.1181],
#         [-1.0000, -0.1024],
#         [-1.0000, -0.0866],
#         [-1.0000, -0.0709],
#         [-1.0000, -0.0551],
#         [-1.0000, -0.0394],
#         [-1.0000, -0.0236],
#         [-1.0000, -0.0079],
#         [-1.0000,  0.0079],
#         [-1.0000,  0.0236],
#         [-1.0000,  0.0394],
#         [-1.0000,  0.0551],
#         [-1.0000,  0.0709],
#         [-1.0000,  0.0866],
#         [-1.0000,  0.1024],
#         [-1.0000,  0.1181],
#         [-1.0000,  0.1339],
#         [-1.0000,  0.1496],
#         [-1.0000,  0.1654],
#         [-1.0000,  0.1811],
#         [-1.0000,  0.1969],
#         [-1.0000,  0.2126],
#         [-1.0000,  0.2283],
#         [-1.0000,  0.2441],
#         [-1.0000,  0.2598],
#         [-1.0000,  0.2756],
#         [-1.0000,  0.2913],
#         [-1.0000,  0.3071],
#         [-1.0000,  0.3228],
#         [-1.0000,  0.3386],
#         [-1.0000,  0.3543],
#         [-1.0000,  0.3701],
#         [-1.0000,  0.3858],
#         [-1.0000,  0.4016],
#         [-1.0000,  0.4173],
#         [-1.0000,  0.4331],
#         [-1.0000,  0.4488],
#         [-1.0000,  0.4646],
#         [-1.0000,  0.4803],
#         [-1.0000,  0.4961],
#         [-1.0000,  0.5118],
#         [-1.0000,  0.5276],
#         [-1.0000,  0.5433],
#         [-1.0000,  0.5591],
#         [-1.0000,  0.5748],
#         [-1.0000,  0.5906],
#         [-1.0000,  0.6063],
#         [-1.0000,  0.6220],
#         [-1.0000,  0.6378],
#         [-1.0000,  0.6535],
#         [-1.0000,  0.6693],
#         [-1.0000,  0.6850],
#         [-1.0000,  0.7008],
#         [-1.0000,  0.7165],
#         [-1.0000,  0.7323],
#         [-1.0000,  0.7480],
#         [-1.0000,  0.7638],
#         [-1.0000,  0.7795],
#         [-1.0000,  0.7953],
#         [-1.0000,  0.8110],
#         [-1.0000,  0.8268],
#         [-1.0000,  0.8425],
#         [-1.0000,  0.8583],
#         [-1.0000,  0.8740],
#         [-1.0000,  0.8898],
#         [-1.0000,  0.9055],
#         [-1.0000,  0.9213],
#         [-1.0000,  0.9370],
#         [-1.0000,  0.9528],
#         [-1.0000,  0.9685],
#         [-1.0000,  0.9843],
#         [-1.0000,  1.0000]])

# %%
fig, axs = plt.subplots(2, 4, figsize=(16, 8))
for i in range(4):
    msk = masks[4, i]
    recon = recons[4, i]
    axs[1, i].imshow(msk)
    axs[0, i].imshow(recon)
    

    axs[0][i].set_title(f"Slot reconstruction {i}")
    axs[1][i].set_title(f"Alpha Mask {i}")

plt.show()

fig, axs = plt.subplots(1, 3, figsize=(16, 8))
axs[0].imshow(images.squeeze(0).cpu().numpy()[4].transpose(1, 2, 0))
axs[0].set_title("Input Image")

axs[1].imshow(flows.squeeze(0).cpu().numpy()[4].transpose(1, 2, 0))
axs[1].set_title("Ground Truth Flow")

axs[2].imshow(recon_all[4].transpose(1, 2, 0))
axs[2].set_title("Predicted Flow")

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print(losses["frame_kl_loss"])
# Out:
# tensor(7.7395e-09, device='cuda:0', grad_fn=<MulBackward0>)

# %%
imgs = torch.ones()

# %%
x = torch.distributions.independent.Independent(images, torch.tensor([0]))
rand = torch.randn_like(images)
lp = x.log_prob(rand)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_147272/3141703677.py in <module>
# ----> 1 x = torch.distributions.independent.Independent(images, torch.tensor([0]))
#       2 rand = torch.randn_like(images)
#       3 lp = x.log_prob(rand)
#
# /om2/user/yyf/miniconda/lib/python3.9/site-packages/torch/distributions/independent.py in __init__(self, base_distribution, reinterpreted_batch_ndims, validate_args)
#      35
#      36     def __init__(self, base_distribution, reinterpreted_batch_ndims, validate_args=None):
# ---> 37         if reinterpreted_batch_ndims > len(base_distribution.batch_shape):
#      38             raise ValueError("Expected reinterpreted_batch_ndims <= len(base_distribution.batch_shape), "
#      39                              "actual {} vs {}".format(reinterpreted_batch_ndims,
#
# AttributeError: 'Tensor' object has no attribute 'batch_shape'

# %%
x
# Out:
# Categorical(probs: torch.Size([1, 6, 3, 128, 128]))

# %%
import einops
a = torch.tensor([[1, 2], [4, 5]])
b = einops.repeat(a, "c d -> b c d", b=2, c=2)
b
# Out:
# tensor([[[1, 2],
#          [4, 5]],
#
#         [[1, 2],
#          [4, 5]]])

# %%
print(recons.shape)
# Out:
# (1, 6, 3, 128, 128)

# %%
a = torch.nn.LayerNorm((64, 128))

# %%
b = torch.rand((4, 64, 128))
b2 = a(b)
b3 = F.softmax(b2, -1)
b3.min(), b3.max()
# Out:
# (tensor(0.0007, grad_fn=<MinBackward1>),
#  tensor(0.0337, grad_fn=<MaxBackward1>))
